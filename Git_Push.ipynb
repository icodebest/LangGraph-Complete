# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata

# Retrieve stored GitHub token securely
GITHUB_TOKEN = userdata.get('GITHUB_TOKEN')

if GITHUB_TOKEN:
    print("✅ GitHub token loaded securely!")
else:
    print("❌ ERROR: GitHub token not found!")
# Out:
# ✅ GitHub token loaded securely!

# %%
# Set your Git credentials
# !git config --global user.email "waleedusmanf22@nutech.edu.pk"
# !git config --global user.name "icodebest"

# %%
# %cd /content/drive/MyDrive/LangGraph-Complete
# Out:
# /content/drive/MyDrive/LangGraph-Complete

# %%
# Update the remote URL to use the token for authentication
# !git remote set-url origin https://icodebest:{GITHUB_TOKEN}@github.com/icodebest/LangGraph-Complete.git

# %%
# !git status

# %%
# !git add .

# %%
# !git commit -m "Module_0 Completed"
# Out:
# [main 34beddd] Module_0 Completed
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git fetch origin
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1.01 KiB | 3.00 KiB/s, done.
# From https://github.com/icodebest/LangGraph-Complete
#    cc5ce7d..13febc4  main       -> origin/main

# %%
# !git pull origin main --rebase
# Out:
# From https://github.com/icodebest/LangGraph-Complete
#  * branch            main       -> FETCH_HEAD
# Successfully rebased and updated refs/heads/main.

# %%
# !git rebase --continue
# Out:
# fatal: No rebase in progress?

# %%
# !git push origin main
# Out:
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (8/8), 8.57 KiB | 548.00 KiB/s, done.
# Total 8 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 1 local object.
# To https://github.com/icodebest/LangGraph-Complete.git
#    13febc4..93250b2  main -> main
